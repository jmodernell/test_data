# %%
import pandas as pd

# %%
data = pd.read_csv('20210311_ops.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-3ae616c244e7> in <module>
# ----> 1 data = pd.read_csv('20210311_ops.csv')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# ...

# %%
data = pd.read_csv('20210311_ops.csv', error_bad_lines=False)
# Out:
# b'Skipping line 18: expected 3 fields, saw 4\nSkipping line 110: expected 3 fields, saw 7\nSkipping line 111: expected 3 fields, saw 7\nSkipping line 112: expected 3 fields, saw 6\nSkipping line 113: expected 3 fields, saw 7\nSkipping line 115: expected 3 fields, saw 7\nSkipping line 116: expected 3 fields, saw 6\nSkipping line 117: expected 3 fields, saw 7\nSkipping line 118: expected 3 fields, saw 7\nSkipping line 119: expected 3 fields, saw 7\nSkipping line 121: expected 3 fields, saw 7\nSkipping line 123: expected 3 fields, saw 7\nSkipping line 124: expected 3 fields, saw 7\nSkipping line 125: expected 3 fields, saw 7\nSkipping line 126: expected 3 fields, saw 7\nSkipping line 127: expected 3 fields, saw 7\nSkipping line 128: expected 3 fields, saw 7\nSkipping line 129: expected 3 fields, saw 7\nSkipping line 130: expected 3 fields, saw 7\nSkipping line 131: expected 3 fields, saw 7\nSkipping line 132: expected 3 fields, saw 7\nSkipping line 134: expected 3 fields, saw 7\nSkippin
# ...

# %%
data.shape
# Out:
# (253, 3)

# %%
data2 = pd.read_csv('20210311_ops.csv', sep='delimiter', header=None)
# Out:
# /Users/jmodernell/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
data2.shape
# Out:
# (13860, 1)

# %%
data2.head()
# Out:
#                                                    0
# 0  Região;Data ;close_date;warehouse;pqr_id;statu...
# 1  Santo Andre;29/10/2021;2021-10-29;STA;90248;2;...
# 2  Sao Paulo;29/10/2021;2021-10-29;CEAGESP;90187;...
# 3  Sao Paulo;29/10/2021;2021-10-29;CEAGESP;90284;...
# 4  Sao Paulo;29/10/2021;2021-10-29;CEAGESP;90285;...

# %%
data3 = pd.read_csv('20210311_ops.csv', sep=';', header=None)

# %%
data3.shape
# Out:
# (13854, 45)

# %%
data3.head()
# Out:
#             0           1           2          3       4       5   \
# 0       Região       Data   close_date  warehouse  pqr_id  status
# 1  Santo Andre  29/10/2021  2021-10-29        STA   90248       2
# 2    Sao Paulo  29/10/2021  2021-10-29    CEAGESP   90187       2
# 3    Sao Paulo  29/10/2021  2021-10-29    CEAGESP   90284       2
# 4    Sao Paulo  29/10/2021  2021-10-29    CEAGESP   90285       2
#
#                         6          7              8           9   ...  \
# 0               created_at       name    detail_name  product_id  ...
# 1  2021-10-29T15:01:57.388  Qualidade         Murcho      133468  ...
# 2  2021-10-29T12:40:13.426     Padrão  Muito pequeno       74194  ...
# 3  2021-10-29T15:44:06.390     Padrão  Muito pequeno       75051  ...
# 4  2021-10-29T15:44:06.402     Padrão  Muito pequeno      112265  ...
#
#              35             36    37             38             39  \
# 0  % invent fct  % invent real  temp  temp_min (°C)  temp_max (°C)
# ...

# %%
data4 = pd.read_csv('20210311_ops.csv', sep=';')

# %%
data4.shape
# Out:
# (13853, 45)

# %%
data4.head()
# Out:
#         Região       Data   close_date warehouse  pqr_id  status  \
# 0  Santo Andre  29/10/2021  2021-10-29       STA   90248       2
# 1    Sao Paulo  29/10/2021  2021-10-29   CEAGESP   90187       2
# 2    Sao Paulo  29/10/2021  2021-10-29   CEAGESP   90284       2
# 3    Sao Paulo  29/10/2021  2021-10-29   CEAGESP   90285       2
# 4    Sao Paulo  29/10/2021  2021-10-29   CEAGESP   90286       2
#
#                 created_at       name    detail_name  product_id  ...  \
# 0  2021-10-29T15:01:57.388  Qualidade         Murcho      133468  ...
# 1  2021-10-29T12:40:13.426     Padrão  Muito pequeno       74194  ...
# 2  2021-10-29T15:44:06.390     Padrão  Muito pequeno       75051  ...
# 3  2021-10-29T15:44:06.402     Padrão  Muito pequeno      112265  ...
# 4  2021-10-29T15:44:40.116     Padrão       Manchado       72308  ...
#
#   % invent fct % invent real  temp temp_min (°C) temp_max (°C) humidity (%)  \
# ...

# %%
data4.columns
# Out:
# Index(['Região', 'Data ', 'close_date', 'warehouse', 'pqr_id', 'status',
#        'created_at', 'name', 'detail_name', 'product_id', 'product_name',
#        'linea_id', 'user_id', 'user_name', 'user_email', 'region_code',
#        'trip_id', 'tracking_code', 'start_time', 'end_time', 'check_in',
#        'check_out', 'microzone', 'order_id', 'usuario_ejecucion',
#        'nome_picker', 'nome_qa', 'nome_condutor', 'mês', 'semana',
#        'dia da semana', 'SKU clean', 'PQR clean', 'slot', 'Inventario dias',
#        '% invent fct', '% invent real', 'temp', 'temp_min (°C)',
#        'temp_max (°C)', 'humidity (%)', 'wind_speed (m/s)',
#        'rain_1h (V ultima hora, mm)', 'rain_3h (V ultima hora, mm)',
#        'Segment'],
#       dtype='object')

# %%
summary_temp = data4.groupby(by=['temp']).count()
summary_temp.head()
# Out:
#        Região  Data   close_date  warehouse  pqr_id  status  created_at  name  \
# temp
# 0         532    532         532        529     532     532         532   532
# 10,65      26     26          26         26      26      26          26    26
# 10,99      33     33          33         33      33      33          33    33
# 11,33      70     70          70         70      70      70          70    70
# 12,69      81     81          81         81      81      81          81    81
#
#        detail_name  product_id  ...  Inventario dias  % invent fct  \
# temp                            ...
# 0              532         532  ...              453           453
# 10,65           26          26  ...               19            19
# 10,99           33          33  ...               27            27
# 11,33           70          70  ...               63            63
# 12,69           81          81  ...               66            66
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20, 8))
sns.scatterplot(x=summary_temp.index, y=summary_temp['pqr_id'])
plt.show()

# %%
corr_matrix = data4.corr()
corr_matrix
# Out:
#                  pqr_id    status  product_id   user_id  check_in  check_out  \
# pqr_id         1.000000 -0.026262    0.172551  0.419160       NaN        NaN
# status        -0.026262  1.000000    0.021471 -0.020867       NaN        NaN
# product_id     0.172551  0.021471    1.000000  0.076121       NaN        NaN
# user_id        0.419160 -0.020867    0.076121  1.000000       NaN        NaN
# check_in            NaN       NaN         NaN       NaN       NaN        NaN
# check_out           NaN       NaN         NaN       NaN       NaN        NaN
# microzone      0.236459  0.003075    0.036504  0.549835       NaN        NaN
# order_id       0.995819 -0.025512    0.170042  0.410263       NaN        NaN
# mês            0.955718 -0.022368    0.172625  0.451351       NaN        NaN
# semana         0.962502 -0.025502    0.173641  0.455034       NaN        NaN
# dia da semana  0.019189 -0.010049    0.023487  0.015751       NaN        NaN
#
# ...

# %%
# Correlation matrix with numeric features' relation to each other & to target variable
# Available cmap options for Correlation Matrix: Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, crest, crest_r, cubehelix, cubehelix_r, flag, flag_r, flare, flare_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, twilight, twilight_r, twilight_shifted, twilight_shifted_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r
ax = sns.heatmap(data4.corr(), annot=True, cmap='seismic', linewidths=0.2) 
fig=plt.gcf()
fig.set_size_inches(18, 18)
plt.title('Correlation between features')
plt.tight_layout()

# Format adjustment to avoid cutting off first & last line
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)

plt.show()
